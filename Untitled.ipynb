# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import seaborn as sns
import os
from textwrap import wrap
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
import eli5
from cleanfunc import load_merge_clean
import re

sns.reset_orig()
# Out:
# C:\Users\cartechr\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\__init__.py:855: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))
# C:\Users\cartechr\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\__init__.py:846: MatplotlibDeprecationWarning:
# The text.latex.unicode rcparam was deprecated in Matplotlib 2.2 and will be removed in 3.1.
#   "2.2", name=key, obj_type="rcparam", addendum=addendum)

# %%
nb_path = os.getcwd()

df = pd.read_excel('{}\CSV\pop.xls'.format(nb_path),skiprows=5, header = [0, 1, 2, 3], skipfooter = 6)
df.head()
# Out:
#      Unnamed: 0_level_0 Unnamed: 1_level_0  \
#      Unnamed: 0_level_1 Unnamed: 1_level_1
#      Unnamed: 0_level_2 Unnamed: 1_level_2
# CODE              LABEL               YEAR
# 0             Australia               2011
# 0             Australia               2012
# 0             Australia               2013
# 0             Australia               2014
# 0             Australia               2015
#
#      ESTIMATED RESIDENT POPULATION (USUAL RESIDENTS, ERP AT 30 JUNE)  \
#                                                              Persons
#                                                           0-14 years
# CODE                                                               %
# 0                                                     -
# 0                                                     -
# 0                                                  18.9
# 0                                                  18.9
# 0                                                  18.9
#
# ...

# %%
df.tail()
# Out:
#           Unnamed: 0_level_0 Unnamed: 1_level_0  \
#           Unnamed: 0_level_1 Unnamed: 1_level_1
#           Unnamed: 0_level_2 Unnamed: 1_level_2
# CODE                   LABEL               YEAR
# 901031003         Jervis Bay               2017
# 901031003         Jervis Bay               2018
# 901041004     Norfolk Island               2016
# 901041004     Norfolk Island               2017
# 901041004     Norfolk Island               2018
#
#           ESTIMATED RESIDENT POPULATION (USUAL RESIDENTS, ERP AT 30 JUNE)  \
#                                                                   Persons
#                                                                0-14 years
# CODE                                                                    %
# 901031003                                               18.5
# 901031003                                                  -
# 901041004                                               17.2
# ...

# %%
unnamed_str = 'Unnamed: [0-9]+_level_[0-9]'
df.columns = [re.sub(unnamed_str, '', ' '.join(col)).strip() for col in df.columns.values]

# %%
df.head()
# Out:
#        LABEL  YEAR  \
# 0  Australia  2011
# 0  Australia  2012
# 0  Australia  2013
# 0  Australia  2014
# 0  Australia  2015
#
#   ESTIMATED RESIDENT POPULATION (USUAL RESIDENTS, ERP AT 30 JUNE) Persons 0-14 years %  \
# 0                                                  -
# 0                                                  -
# 0                                               18.9
# 0                                               18.9
# 0                                               18.9
#
#   ESTIMATED RESIDENT POPULATION (USUAL RESIDENTS, ERP AT 30 JUNE) Persons 15-24 years %  \
# 0                                                  -
# 0                                                  -
# 0                                               13.5
# 0                                               13.3
# 0                                               13.2
#
#   ESTIMATED RESIDENT POPULATION (USUAL RESIDENTS, ERP AT 30 JUNE) Persons 25-34 years %  \
# ...

# %%
import importlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import seaborn as sns
import os
from textwrap import wrap
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA
import eli5
from cleanfunc import load_merge_clean, sort_series_abs
import re
from sklearn.metrics import r2_score
#importlib.reload(cleanfunc)

# %%
df = load_merge_clean()
df.head()
# Out:
# C:\Users\chris\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2901: DtypeWarning:
#
# Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#
# C:\Users\chris\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\chris\Anaconda3\lib\site-packages\pandas\core\generic.py:5434: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                    NUMBER OF BUSINESSES Number of non-employing businesses no.  \
# LABEL
# Braidwood                                                      404.0
# Karabar                                                        209.0
# Queanbeyan                                                     402.0
# Queanbeyan - East                                              292.0
# Queanbeyan Region                                              915.0
#
#                    NUMBER OF BUSINESSES 1-4 employees no.  \
# LABEL
# Braidwood                                           149.0
# Karabar                                             106.0
# Queanbeyan                                          193.0
# Queanbeyan - East                                   144.0
# Queanbeyan Region                                   487.0
#
#                    NUMBER OF BUSINESSES 5-19 employees no.  \
# LABEL
# Braidwood                                             33.0
# Karabar                                               17.0
# Queanbeyan                                            89.0
# Queanbeyan - East                                     90.0
# Queanbeyan Region                                    119.0
#
#                    NUMBER OF BUSINESSES 20 or more employees no.  \
# LABEL
# Braidwood                                                    3.0
# Karabar                                                      3.0
# Queanbeyan                                                  27.0
# Queanbeyan - East                                           24.0
# Queanbeyan Region                                            9.0
#
#                    NUMBER OF BUSINESSES Total number of businesses no.  \
# LABEL
# Braidwood                                                      589.0
# Karabar                                                        335.0
# Queanbeyan                                                     712.0
# Queanbeyan - East                                              554.0
# Queanbeyan Region                                             1526.0
#
#                    BUSINESS ENTRIES Number of non-employing business entries  no.  \
# LABEL
# Braidwood                                                       42.0
# Karabar                                                         25.0
# Queanbeyan                                                      75.0
# Queanbeyan - East                                               39.0
# Queanbeyan Region                                              149.0
#
#                    BUSINESS ENTRIES 1-4 employees no.  \
# LABEL
# Braidwood                                        15.0
# Karabar                                          19.0
# Queanbeyan                                       32.0
# Queanbeyan - East                                23.0
# Queanbeyan Region                                50.0
#
#                    BUSINESS ENTRIES 5-19 employees no.  \
# LABEL
# Braidwood                                     6.550351
# Karabar                                       6.550351
# Queanbeyan                                    5.000000
# Queanbeyan - East                             4.000000
# Queanbeyan Region                             3.000000
#
#                    BUSINESS ENTRIES 20 or more employees no.  \
# LABEL
# Braidwood                                           3.855263
# Karabar                                             3.855263
# Queanbeyan                                          3.855263
# Queanbeyan - East                                   3.855263
# Queanbeyan Region                                   3.855263
#
#                    BUSINESS ENTRIES Total number of business entries no.  \
# LABEL
# Braidwood                                                       52.0
# Karabar                                                         38.0
# Queanbeyan                                                     111.0
# Queanbeyan - East                                               67.0
# Queanbeyan Region                                              202.0
#
#                       ...      RELIGIOUS AFFILIATION Judaism   %  \
# LABEL                 ...
# Braidwood             ...                               0.748598
# Karabar               ...                               0.748598
# Queanbeyan            ...                               0.100000
# Queanbeyan - East     ...                               0.200000
# Queanbeyan Region     ...                               0.748598
#
#                    RELIGIOUS AFFILIATION Other Religions   %  \
# LABEL
# Braidwood                                                0.5
# Karabar                                                  0.8
# Queanbeyan                                               2.1
# Queanbeyan - East                                        2.6
# Queanbeyan Region                                        0.6
#
#                    RELIGIOUS AFFILIATION Secular Beliefs, Other Spiritual Beliefs and No Religious Affiliation  %  \
# LABEL
# Braidwood                                                       35.3
# Karabar                                                         24.5
# Queanbeyan                                                      28.5
# Queanbeyan - East                                               27.4
# Queanbeyan Region                                               32.5
#
#                    RELIGIOUS AFFILIATION Inadequately described or not stated   %  \
# LABEL
# Braidwood                                                       14.6
# Karabar                                                          8.1
# Queanbeyan                                                      10.5
# Queanbeyan - East                                                9.2
# Queanbeyan Region                                               12.2
#
#                    AUSTRALIAN CITIZENSHIP Australian citizen  %  \
# LABEL
# Braidwood                                                  85.0
# Karabar                                                    89.7
# Queanbeyan                                                 80.6
# Queanbeyan - East                                          82.0
# Queanbeyan Region                                          87.8
#
#                    AUSTRALIAN CITIZENSHIP Not an Australian citizen  %  \
# LABEL
# Braidwood                                                        3.2
# Karabar                                                          4.0
# Queanbeyan                                                      11.2
# Queanbeyan - East                                               11.4
# Queanbeyan Region                                                2.6
#
#                    AUSTRALIAN CITIZENSHIP Australian Citizenship - Not stated  %  \
# LABEL
# Braidwood                                                       11.7
# Karabar                                                          6.2
# Queanbeyan                                                       8.2
# Queanbeyan - East                                                6.4
# Queanbeyan Region                                                9.7
#
#                    SPEAKS A LANGUAGE OTHER THAN ENGLISH AT HOME Proportion of total population  %  \
# LABEL
# Braidwood                                                        3.4
# Karabar                                                         13.5
# Queanbeyan                                                      21.2
# Queanbeyan - East                                               20.4
# Queanbeyan Region                                                5.8
#
#                          lat        long
# LABEL
# Braidwood         -35.444450  149.799675
# Karabar           -35.375943  149.232872
# Queanbeyan        -35.352466  149.233725
# Queanbeyan - East -35.345549  149.246507
# Queanbeyan Region -35.352466  149.233725
#
# [5 rows x 456 columns]

# %%
import folium


m = folium.Map(location=[45.5236, -122.6750])

# %%
# !pip install plotly
# Out:
# Collecting plotly
#   Downloading https://files.pythonhosted.org/packages/ff/75/3982bac5076d0ce6d23103c03840fcaec90c533409f9d82c19f54512a38a/plotly-3.10.0-py2.py3-none-any.whl (41.5MB)
# Requirement already satisfied: decorator>=4.0.6 in c:\users\chris\anaconda3\lib\site-packages (from plotly) (4.3.0)
# Requirement already satisfied: nbformat>=4.2 in c:\users\chris\anaconda3\lib\site-packages (from plotly) (4.4.0)
# Requirement already satisfied: requests in c:\users\chris\anaconda3\lib\site-packages (from plotly) (2.19.1)
# Collecting retrying>=1.3.3 (from plotly)
#   Downloading https://files.pythonhosted.org/packages/44/ef/beae4b4ef80902f22e3af073397f079c96969c69b2c7d52a57ea9ae61c9d/retrying-1.3.3.tar.gz
# Requirement already satisfied: pytz in c:\users\chris\anaconda3\lib\site-packages (from plotly) (2018.5)
# Requirement already satisfied: six in c:\users\chris\anaconda3\lib\site-packages (from plotly) (1.11.0)
# Requirement already satisfied: ipython_genutils in c:\users\chris\anaconda3\lib\site-packages (from nbformat>=4.2->plotly) (0.2.0)
# Requirement already satisfied: traitlets>=4.1 in c:\users\chris\anaconda3\lib\site-packages (from nbformat>=4.2->plotly) (4.3.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\chris\anaconda3\lib\site-packages (from nbformat>=4.2->plotly) (2.6.0)
# Requirement already satisfied: jupyter_core in c:\users\chris\anaconda3\lib\site-packages (from nbformat>=4.2->plotly) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chris\anaconda3\lib\site-packages (from requests->plotly) (2018.8.24)
# Requirement already satisfied: urllib3<1.24,>=1.21.1 in c:\users\chris\anaconda3\lib\site-packages (from requests->plotly) (1.23)
# Requirement already satisfied: idna<2.8,>=2.5 in c:\users\chris\anaconda3\lib\site-packages (from requests->plotly) (2.7)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\chris\anaconda3\lib\site-packages (from requests->plotly) (3.0.4)
# Building wheels for collected packages: retrying
#   Building wheel for retrying (setup.py): started
#   Building wheel for retrying (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\chris\AppData\Local\pip\Cache\wheels\d7\a9\33\acc7b709e2a35caa7d4cae442f6fe6fbf2c43f80823d46460c
# Successfully built retrying
# Installing collected packages: retrying, plotly
# Successfully installed plotly-3.10.0 retrying-1.3.3
# You are using pip version 19.0.3, however version 19.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
cycle_col = 'METHOD OF TRAVEL TO WORK - EMPLOYED PERSONS Used one method - Bicycle no.'

data = [go.Choropleth(
    colorscale = scl,
    autocolorscale = False,
    locations = df.index,
    z = df[cycle_col].astype(float),
    #locationmode = 'USA-states',
    #text = df['text'],
    marker = go.choropleth.Marker(
        line = go.choropleth.marker.Line(
            color = 'rgb(255,255,255)',
            width = 2
        )),
    colorbar = go.choropleth.ColorBar(
        title = "Millions USD")
)]

layout = go.Layout(
    title = go.layout.Title(
        text = 'Test'
    ),
    geo = go.layout.Geo(
        scope = 'asia',
        projection = go.layout.geo.Projection(type = 'albers usa'),
        showlakes = True,
        lakecolor = 'rgb(255, 255, 255)'),
)

fig = go.Figure(data = data, layout = layout)
py.iplot(fig, filename = 'd3-cloropleth-map')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~chrismelba/0 or inside your plot.ly account where it is named 'd3-cloropleth-map'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~chrismelba/0.embed" height="525px" width="100%"></iframe>
